# %%
import haversine as hs   
from haversine import Unit

# %%
commune_list = ["Anniviers", "Chalais", "Chippis", "Crans-Montana", "Grône", "Icogne", "Lens", "Noble-Contrée", "Saint-Léonard", "Sierre"]
pts_list = [(46.183056, 7.598889), (46.265556, 7.507222), (46.281944, 7.544444), (46.311944, 7.482778), (46.253056, 7.458889), (46.292500, 7.440278), (46.278889, 7.445000), (46.312500, 7.548333), (46.250000, 7.416667), (46.293056, 7.533056)]

len(commune_list), len(pts_list)
# Out:
# (10, 10)

# %%
import pandas as pd
df = pd.DataFrame(index=commune_list)

for i in range(len(commune_list)):
    liste = [hs.haversine(pts_list[i],pts_list[j],unit=Unit.KILOMETERS) for j in range(len(commune_list))]
    df[commune_list[i]] = liste

df
# Out:
#                Anniviers    Chalais    Chippis  Crans-Montana      Grône  \
# Anniviers       0.000000  11.570791  11.766320      16.885382  13.289296
# Chalais        11.570791   0.000000   3.391932       5.489441   3.967283
# Chippis        11.766320   3.391932   0.000000       5.794213   7.319029
# Crans-Montana  16.885382   5.489441   5.794213       0.000000   6.800530
# Grône          13.289296   3.967283   7.319029       6.800530   0.000000
# Icogne         17.231069   5.953580   8.089789       3.915829   4.613352
# Lens           15.927012   5.007014   7.649837       4.683366   3.064499
# Noble-Contrée  14.909289   6.101343   3.410788       5.035369   9.536005
# Saint-Léonard  15.873699   7.173709  10.444802       8.558921   3.264215
# Sierre         13.237992   3.645861   1.514078       4.396425   7.230409
#
#                   Icogne       Lens  Noble-Contrée  Saint-Léonard     Sierre
# Anniviers      17.231069  15.927012      14.909289      15.873699  13.237992
# ...

# %%
warehouse_loc = (46.281778, 7.512944)
liste = [hs.haversine(warehouse_loc,pts_list[j],unit=Unit.KILOMETERS) for j in range(len(commune_list))]
df["Warehouse"] = liste

df
# Out:
#                Anniviers    Chalais    Chippis  Crans-Montana      Grône  \
# Anniviers       0.000000  11.570791  11.766320      16.885382  13.289296
# Chalais        11.570791   0.000000   3.391932       5.489441   3.967283
# Chippis        11.766320   3.391932   0.000000       5.794213   7.319029
# Crans-Montana  16.885382   5.489441   5.794213       0.000000   6.800530
# Grône          13.289296   3.967283   7.319029       6.800530   0.000000
# Icogne         17.231069   5.953580   8.089789       3.915829   4.613352
# Lens           15.927012   5.007014   7.649837       4.683366   3.064499
# Noble-Contrée  14.909289   6.101343   3.410788       5.035369   9.536005
# Saint-Léonard  15.873699   7.173709  10.444802       8.558921   3.264215
# Sierre         13.237992   3.645861   1.514078       4.396425   7.230409
#
#                   Icogne       Lens  Noble-Contrée  Saint-Léonard     Sierre  \
# Anniviers      17.231069  15.927012      14.909289      15.873699  13.237992
# ...

# %%
df.to_excel("distances.xlsx")

# %%
alts_list = ["848/1691", "522/1330", "526/532", "577/1546", "503/1064", "1034/1160", "758/1637", "600/907", "500/507", "500/559"]

for i in range(len(commune_list)):
    alt = alts_list[i].split("/")
    
    alt = [int(x) for x in alt]
    df.loc[commune_list[i], "Altitude"] = alt[0]
    df.loc[commune_list[i], "Max Altitude"] = alt[1]

# %%
import pandas as pd

df = pd.read_excel("distances.xlsx", index_col=0)
df
# Out:
#                Anniviers    Chalais    Chippis  Crans-Montana      Grône  \
# Anniviers       7.185000  11.570791  11.766320      16.885382  13.289296
# Chalais        11.570791   1.055000   3.391932       5.489441   3.967283
# Chippis        11.766320   3.391932   0.186000       5.794213   7.319029
# Crans-Montana  16.885382   5.489441   5.794213       2.893000   6.800530
# Grône          13.289296   3.967283   7.319029       6.800530   0.736000
# Icogne         17.231069   5.953580   8.089789       3.915829   4.613352
# Lens           15.927012   5.007014   7.649837       4.683366   3.064499
# Noble-Contrée  14.909289   6.101343   3.410788       5.035369   9.536005
# Saint-Léonard  15.873699   7.173709  10.444802       8.558921   3.264215
# Sierre         13.237992   3.645861   1.514078       4.396425   7.230409
#
#                   Icogne       Lens  Noble-Contrée  Saint-Léonard     Sierre  \
# Anniviers      17.231069  15.927012      14.909289      15.873699  13.237992
# ...

# %%
df.loc["Anniviers", "Chippis"]
# Out:
# np.float64(11.76632007463956)

# %%
import numpy.random as npr

radius = df.loc["Anniviers", "Anniviers"]
print(int(radius/2*1000), int(radius*1000))
npr.random_integers(low = int(radius/2*1000), high = int(radius*1000))/1000
# Out:
# 3592 7185
# C:\Users\Julien\AppData\Local\Temp\ipykernel_34364\3927246082.py:5: DeprecationWarning: This function is deprecated. Please call randint(3592, 7185 + 1) instead
#   npr.random_integers(low = int(radius/2*1000), high = int(radius*1000))/1000
# np.float64(4.486)

# %%
import pandas as pd
df = pd.read_excel("distances.xlsx", index_col=0)

df
# Out:
#                Anniviers    Chalais    Chippis  Crans-Montana      Grône  \
# Anniviers       7.185000  11.570791  11.766320      16.885382  13.289296
# Chalais        11.570791   1.055000   3.391932       5.489441   3.967283
# Chippis        11.766320   3.391932   0.186000       5.794213   7.319029
# Crans-Montana  16.885382   5.489441   5.794213       2.893000   6.800530
# Grône          13.289296   3.967283   7.319029       6.800530   0.736000
# Icogne         17.231069   5.953580   8.089789       3.915829   4.613352
# Lens           15.927012   5.007014   7.649837       4.683366   3.064499
# Noble-Contrée  14.909289   6.101343   3.410788       5.035369   9.536005
# Saint-Léonard  15.873699   7.173709  10.444802       8.558921   3.264215
# Sierre         13.237992   3.645861   1.514078       4.396425   7.230409
#
#                   Icogne       Lens  Noble-Contrée  Saint-Léonard     Sierre  \
# Anniviers      17.231069  15.927012      14.909289      15.873699  13.237992
# ...

# %%
altitudes = pd.DataFrame()

alts = ["848/1691", "522/1330", "526/532" , "626/1546", "503/1064", "1034/1160", "626/1648", "600/907", "500/550", "500/559"]

for i in range(len(df.columns)-1):
    altitudes[df.columns[i]] = [int(x) for x in alts[i].split("/")]

altitudes
# Out:
#    Anniviers  Chalais  Chippis  Crans-Montana  Grône  Icogne  Lens  \
# 0        848      522      526            626    503    1034   626
# 1       1691     1330      532           1546   1064    1160  1648
#
#    Noble-Contrée  Saint-Léonard  Sierre
# 0            600            500     500
# 1            907            550     559

# %%
c_i = pd.read_excel("communes_infos.xlsx", index_col=0)

c_i
# Out:
#           Anniviers  Chalais  Chippis  Crans-Montana  Grône  Icogne  Lens  \
# Commune
# Radius         7185     1055      186           2893    736     880  2595
# Citizens       2790     3927     1615          10496   2556     640  4570
# Density          11      161      816            176    121      26   329
#
#           Noble-Contrée  Saint-Léonard  Sierre
# Commune
# Radius              945           1110    4950
# Citizens           4693           2628   17829
# Density             721            674     930

# %%
df = pd.read_excel("altitudes.xlsx", index_col=0)

df
# Out:
#    Anniviers  Chalais  Chippis  Crans-Montana  Grône  Icogne  Lens  \
# 0        848      522      526            626    503    1034   626
# 1       1691     1330      532           1546   1064    1160  1648
#
#    Noble-Contrée  Saint-Léonard  Sierre
# 0            600            500     500
# 1            907            550     559

# %%
df.index = ["min", "max"]
df
# Out:
#      Anniviers  Chalais  Chippis  Crans-Montana  Grône  Icogne  Lens  \
# min        848      522      526            626    503    1034   626
# max       1691     1330      532           1546   1064    1160  1648
#
#      Noble-Contrée  Saint-Léonard  Sierre
# min            600            500     500
# max            907            550     559

# %%
df.to_excel("altitudes.xlsx")

# %%
import pandas as pd

df = pd.read_csv("hourly_share_of_daily_demand.csv", index_col=0)
df
# Out:
#                  10        11        12        13        14        15  \
# Day
# Monday     0.014244  0.091127  0.121990  0.116121  0.101782  0.065961
# Tuesdasy   0.007947  0.079539  0.105516  0.093386  0.081527  0.056211
# Wednesday  0.010731  0.081911  0.112080  0.103407  0.085752  0.057575
# Thursday   0.007926  0.085804  0.112023  0.105688  0.089659  0.053598
# Friday     0.009466  0.062930  0.089586  0.086535  0.073997  0.047437
# Saturday   0.008689  0.058849  0.087440  0.101702  0.092376  0.068665
# Sunday     0.006633  0.060557  0.087936  0.103775  0.099504  0.067680
#
#                  16        17        18        19        20        21  \
# Day
# Monday     0.063150  0.066170  0.093710  0.094963  0.074793  0.058003
# Tuesdasy   0.061139  0.070039  0.103648  0.108441  0.100201  0.080917
# Wednesday  0.066469  0.074206  0.101954  0.097276  0.085807  0.068351
# Thursday   0.053693  0.060034  0.089858  0.096982  0.094809  0.083453
# ...

# %%
df.loc["Monday"]["13"]
# Out:
# 0.116120945

# %%
import numpy as np
commune_info_df = pd.read_csv("weekly_daily_demand.csv", index_col=0)
hourly_share_of_daily_demand = df.loc["Tueasd"]["13"]
demand_per_commune = commune_info_df.loc[:, "demand_"+"Monday"].to_numpy()*commune_info_df.loc[:, "weekly_fast_food_demand"].to_numpy()/commune_info_df.loc[:, "weekly_demand"].to_numpy()
hourly_demand = hourly_share_of_daily_demand * demand_per_commune
threshold_fct = np.vectorize(lambda x: x if x >= 7 else 0)
hourly_demand = threshold_fct(hourly_demand)
hourly_demand, hourly_demand.shape
# Out:
# (array([ 0,  9,  0, 25,  0,  0, 11, 11,  0, 43]), (10,))

# %%
import pandas as pd
altitudes = pd.read_excel("altitudes.xlsx", index_col=0)
altitudes
# Out:
#      Anniviers  Chalais  Chippis  Crans-Montana  Grône  Icogne  Lens  \
# min        848      522      526            626    503    1034   626
# max       1691     1330      532           1546   1064    1160  1648
#
#      Noble-Contrée  Saint-Léonard  Sierre
# min            600            500     500
# max            907            550     559

# %%
altitudes.loc["min", "Sierre"]
# Out:
# 500
